# %%
from prompts import *

with open('raw_prompts/graph_extraction_prompt.txt', 'w') as f:
    f.write(graph_extraction_prompt(""))

# %%
# Save entity resolution prompt  
with open('raw_prompts/entity_resolution_prompt.txt', 'w') as f:
    f.write(prompt_er([]))

# %%
  # Save community summarization prompt
with open('raw_prompts/community_summarization_prompt.txt', 'w') as f:
    f.write(summarize_community(""))
