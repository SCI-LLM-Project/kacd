# %% [markdown]
# # This notebook is meant as a playground to analyze results and will constantly be updated

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="neo4j.*")

# %%
kgllm_full["Plausibility"].value_counts()

# %%
kgllm_proto["Plausibility"].value_counts()

# %%
kgllm_full["Label"].value_counts()

# %%
kgllm_proto["Label"].value_counts()

# %%
kgllm_full

# %%
kgllm_full = pd.read_csv("../results/kg+llm_full.csv").drop(columns=["Unnamed: 0"])
kgllm_proto = pd.read_csv("../results/kg+llm_proto.csv").drop(columns=["Unnamed: 0"])

# %%
tps = kgllm_proto[(kgllm_proto["Plausibility"] == True) & (kgllm_proto["Label"] == True)]["Plausibility"].count()
fns = kgllm_proto[(kgllm_proto["Plausibility"] == False) & (kgllm_proto["Label"] == True)]["Plausibility"].count()

tps / (tps + fns)

# %%
tps, fns

# %%
tps = kgllm_full[(kgllm_full["Plausibility"] == True) & (kgllm_full["Label"] == True)]["Plausibility"].count()
fns = kgllm_full[(kgllm_full["Plausibility"] == False) & (kgllm_full["Label"] == True)]["Plausibility"].count()
tps / (tps + fns)

# %%
tps, fns

# %%
raw = pd.read_csv("../data/proto.csv")
raw[raw["type_inference"] == "tp"]["type_inference"].count()

# %%
raw[raw["type_inference"] == "fn"]["type_inference"].count()

# %% [markdown]
# # Causal Lit

# %%
pd.read_csv("../results/kg+llm_full_causal_literature.csv").value_counts("Causal Literature")

# %%
pd.read_csv("../results/llm_full_causal_literature.csv").value_counts("Causal Literature")

# %%
pd.read_csv("../results/llm+rag_full_causal_literature.csv").value_counts("Causal Literature")
